# %% [markdown]
# Извлечение дескрипторов из записей SMILES отобранных молекул

# %%
import pandas as pd

# Загрузка датасета и вывод первых 5 строк
df = pd.read_csv('dataset_filtered.csv')
df = df.drop(columns=['Standard Relation', 'Standard Units'])
df.head()
# Out:
#                                               Smiles  Standard Value
# 0  O=S(=O)(c1ccc(C(F)(F)F)cc1)N1C2Cc3[nH]ncc3C1CC...            36.0
# 1  O=S(=O)(c1ccc(C(F)(F)F)nc1)N1C2Cc3[nH]ncc3C1CC...             4.0
# 2  COc1cc(-c2nnc3n2CCCN3C(C)c2c(F)cc(F)cc2F)ccc1-...           342.0
# 3  COc1cc(-c2nnc3n2CCCN3Cc2ccc(Cl)c(Cl)c2)ccc1-n1...           126.0
# 4  COc1cc(-c2onc3c2CCCN3[C@@H](C)c2ccccc2)ccc1-n1...           537.0

# %% [markdown]
# Импорт необходимых библиотек

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import Descriptors

# %%
# Получение списка доступных дескрипторов
descriptor_names = list(rdMolDescriptors.Properties.GetAvailableProperties())
get_descriptors = rdMolDescriptors.Properties(descriptor_names)
num_descriptors = len(descriptor_names)

# Инициализация пустой матрицы для дескрипторов
descriptors_set = np.empty((0, num_descriptors), float)

# Расчет дескрипторов
for _, row in df.iterrows():
    smiles = row['Smiles']
    molecule = Chem.MolFromSmiles(smiles)

    if molecule is not None:
        descriptor = np.array(get_descriptors.ComputeProperties(molecule)).reshape((-1, num_descriptors))
        descriptors_set = np.append(descriptors_set, descriptor, axis=0)

df_descriptors = pd.DataFrame(descriptors_set, columns=descriptor_names)

# Объединение существующего датасета с новыми дескрипторами
df_rdkit = pd.concat([df, df_descriptors], axis=1)

# %% [markdown]
# Выводим информацию о новом датасете с десткрипторами

# %%
df_rdkit.head()
# Out:
#                                               Smiles  Standard Value  \
# 0  O=S(=O)(c1ccc(C(F)(F)F)cc1)N1C2Cc3[nH]ncc3C1CC...            36.0
# 1  O=S(=O)(c1ccc(C(F)(F)F)nc1)N1C2Cc3[nH]ncc3C1CC...             4.0
# 2  COc1cc(-c2nnc3n2CCCN3C(C)c2c(F)cc(F)cc2F)ccc1-...           342.0
# 3  COc1cc(-c2nnc3n2CCCN3Cc2ccc(Cl)c(Cl)c2)ccc1-n1...           126.0
# 4  COc1cc(-c2onc3c2CCCN3[C@@H](C)c2ccccc2)ccc1-n1...           537.0
#
#       exactmw      amw  lipinskiHBA  lipinskiHBD  NumRotatableBonds  NumHBD  \
# 0  513.144631  513.545          7.0          1.0                4.0     1.0
# 1  466.108660  466.460          6.0          1.0                3.0     1.0
# 2  468.188544  468.483          7.0          0.0                5.0     0.0
# 3  468.123215  469.376          7.0          0.0                5.0     0.0
# 4  414.205576  414.509          6.0          0.0                5.0     0.0
#
#    NumHBA  NumHeavyAtoms  ...      chi0n      chi1n     chi2n     chi3n  \
# 0     5.0           36.0  ...  18.929067  11.528472  7.205882  7.205882
# 1     4.0           32.0  ...  16.550417   9.993499  6.229030  6.229030
# 2     7.0           34.0  ...  18.965546  10.907253  6.125779  6.125779
# 3     7.0           32.0  ...  17.794688  10.347161  5.609080  5.609080
# 4     6.0           31.0  ...  18.077524  10.649493  6.046511  6.046511
#
#       chi4n  hallKierAlpha     kappa1    kappa2    kappa3       Phi
# 0  5.506248          -3.44  22.988319  8.308724  3.824418  5.305655
# 1  4.848409          -2.79  21.076572  7.376896  3.394202  4.858740
# 2  4.484056          -3.82  21.996100  8.510579  3.683284  5.505869
# 3  4.059013          -3.03  20.849495  8.483873  3.823881  5.527639
# 4  4.384465          -3.54  19.425078  7.945994  3.478645  4.979082
#
# [5 rows x 45 columns]

# %%
df_rdkit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3041 entries, 0 to 3040
# Data columns (total 45 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Smiles                           3041 non-null   object
#  1   Standard Value                   3041 non-null   float64
#  2   exactmw                          3041 non-null   float64
#  3   amw                              3041 non-null   float64
#  4   lipinskiHBA                      3041 non-null   float64
#  5   lipinskiHBD                      3041 non-null   float64
#  6   NumRotatableBonds                3041 non-null   float64
#  7   NumHBD                           3041 non-null   float64
#  8   NumHBA                           3041 non-null   float64
#  9   NumHeavyAtoms                    3041 non-null   float64
#  10  NumAtoms                         3041 non-null   float64
#  11  NumHeteroatoms                   3041 non-null   float64
#  12  NumAmideBonds                    3041 non-null   float64
#  13  FractionCSP3                     3041 non-null   float64
#  14  NumRings                         3041 non-null   float64
#  15  NumAromaticRings                 3041 non-null   float64
#  16  NumAliphaticRings                3041 non-null   float64
#  17  NumSaturatedRings                3041 non-null   float64
#  18  NumHeterocycles                  3041 non-null   float64
#  19  NumAromaticHeterocycles          3041 non-null   float64
#  20  NumSaturatedHeterocycles         3041 non-null   float64
#  21  NumAliphaticHeterocycles         3041 non-null   float64
#  22  NumSpiroAtoms                    3041 non-null   float64
#  23  NumBridgeheadAtoms               3041 non-null   float64
#  24  NumAtomStereoCenters             3041 non-null   float64
#  25  NumUnspecifiedAtomStereoCenters  3041 non-null   float64
#  26  labuteASA                        3041 non-null   float64
#  27  tpsa                             3041 non-null   float64
#  28  CrippenClogP                     3041 non-null   float64
#  29  CrippenMR                        3041 non-null   float64
#  30  chi0v                            3041 non-null   float64
#  31  chi1v                            3041 non-null   float64
#  32  chi2v                            3041 non-null   float64
#  33  chi3v                            3041 non-null   float64
#  34  chi4v                            3041 non-null   float64
#  35  chi0n                            3041 non-null   float64
#  36  chi1n                            3041 non-null   float64
#  37  chi2n                            3041 non-null   float64
#  38  chi3n                            3041 non-null   float64
#  39  chi4n                            3041 non-null   float64
#  40  hallKierAlpha                    3041 non-null   float64
#  41  kappa1                           3041 non-null   float64
#  42  kappa2                           3041 non-null   float64
#  43  kappa3                           3041 non-null   float64
#  44  Phi                              3041 non-null   float64
# dtypes: float64(44), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# Фильтрация по коэффициенту корреляции

# %%
# установка библиотеки sklearn
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\nastj\appdata\local\programs\python\python311\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\nastj\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\nastj\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nastj\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nastj\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.preprocessing import LabelEncoder

# Кодирование SMILES
label_encoder = LabelEncoder()
df_rdkit['smiles_encoded'] = label_encoder.fit_transform(df_rdkit['Smiles'])

# Сохранение целевого столбца
df_target = pd.DataFrame()
df_target['Standard Value'] = df_rdkit['Standard Value']
df_target['smiles_encoded'] = df_rdkit['smiles_encoded']
df_rdkit.drop(columns=['Standard Value', 'Smiles'], inplace=True, axis=1)

# %%
# Вычисление матрицы корреляции
corr_matrix = df_rdkit.corr()

# Выбор дескрипторов с корреляцией > 0.8 или < -0.8
high_corr_descriptors = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > 0.8:
            high_corr_descriptors.add(corr_matrix.columns[i])

# Удаление выбранных дескрипторов
data_filtered = df_rdkit.drop(high_corr_descriptors, axis=1)

# %%
# Вывод информации по оставшимся дескрипторам
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3041 entries, 0 to 3040
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   exactmw                          3041 non-null   float64
#  1   FractionCSP3                     3041 non-null   float64
#  2   NumRings                         3041 non-null   float64
#  3   NumAromaticRings                 3041 non-null   float64
#  4   NumAliphaticRings                3041 non-null   float64
#  5   NumHeterocycles                  3041 non-null   float64
#  6   NumAromaticHeterocycles          3041 non-null   float64
#  7   NumSaturatedHeterocycles         3041 non-null   float64
#  8   NumAliphaticHeterocycles         3041 non-null   float64
#  9   NumSpiroAtoms                    3041 non-null   float64
#  10  NumBridgeheadAtoms               3041 non-null   float64
#  11  NumAtomStereoCenters             3041 non-null   float64
#  12  NumUnspecifiedAtomStereoCenters  3041 non-null   float64
#  13  CrippenClogP                     3041 non-null   float64
#  14  hallKierAlpha                    3041 non-null   float64
#  15  smiles_encoded                   3041 non-null   int64
# dtypes: float64(15), int64(1)
# memory usage: 380.3 KB

# %% [markdown]
# Объедение столбцов-дескрипторов и целевого столбца

# %%
merged_df = pd.merge(df_target, data_filtered, on='smiles_encoded', how='right')
merged_df.head()
# Out:
#    Standard Value  smiles_encoded     exactmw  FractionCSP3  NumRings  \
# 0            36.0            2181  513.144631      0.280000       6.0
# 1         10457.0            2181  513.144631      0.280000       6.0
# 2            40.0            2181  513.144631      0.280000       6.0
# 3         29717.0            2181  513.144631      0.280000       6.0
# 4             4.0            2205  466.108660      0.333333       5.0
#
#    NumAromaticRings  NumAliphaticRings  NumHeterocycles  \
# 0               4.0                2.0              4.0
# 1               4.0                2.0              4.0
# 2               4.0                2.0              4.0
# 3               4.0                2.0              4.0
# 4               3.0                2.0              4.0
#
#    NumAromaticHeterocycles  NumSaturatedHeterocycles  \
# 0                      2.0                       1.0
# 1                      2.0                       1.0
# 2                      2.0                       1.0
# 3                      2.0                       1.0
# 4                      2.0                       1.0
#
#    NumAliphaticHeterocycles  NumSpiroAtoms  NumBridgeheadAtoms  \
# 0                       2.0            0.0                 2.0
# 1                       2.0            0.0                 2.0
# 2                       2.0            0.0                 2.0
# 3                       2.0            0.0                 2.0
# 4                       2.0            0.0                 2.0
#
#    NumAtomStereoCenters  NumUnspecifiedAtomStereoCenters  CrippenClogP  \
# 0                   3.0                              3.0        4.8485
# 1                   3.0                              3.0        4.8485
# 2                   3.0                              3.0        4.8485
# 3                   3.0                              3.0        4.8485
# 4                   3.0                              3.0        4.1969
#
#    hallKierAlpha
# 0          -3.44
# 1          -3.44
# 2          -3.44
# 3          -3.44
# 4          -2.79

# %% [markdown]
# Удаление дубликатов и пропущенных значений

# %%
merged_df = merged_df.drop_duplicates()
merged_df = merged_df.dropna()

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3041 entries, 0 to 5076
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Standard Value                   3041 non-null   float64
#  1   smiles_encoded                   3041 non-null   int64
#  2   exactmw                          3041 non-null   float64
#  3   FractionCSP3                     3041 non-null   float64
#  4   NumRings                         3041 non-null   float64
#  5   NumAromaticRings                 3041 non-null   float64
#  6   NumAliphaticRings                3041 non-null   float64
#  7   NumHeterocycles                  3041 non-null   float64
#  8   NumAromaticHeterocycles          3041 non-null   float64
#  9   NumSaturatedHeterocycles         3041 non-null   float64
#  10  NumAliphaticHeterocycles         3041 non-null   float64
#  11  NumSpiroAtoms                    3041 non-null   float64
#  12  NumBridgeheadAtoms               3041 non-null   float64
#  13  NumAtomStereoCenters             3041 non-null   float64
#  14  NumUnspecifiedAtomStereoCenters  3041 non-null   float64
#  15  CrippenClogP                     3041 non-null   float64
#  16  hallKierAlpha                    3041 non-null   float64
# dtypes: float64(16), int64(1)
# memory usage: 427.6 KB

# %% [markdown]
# Сохранение подгатовленного датасета для обучения модели

# %%
merged_df.to_csv('prepared_dataset.csv', index=False)
